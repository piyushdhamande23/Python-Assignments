# %%
#Question-1
# Create five Numbers  Variables and Assign Some Values in it and display the Output of  that Variables

a=4
b=5
c=15
d=20
e=26

print("the values are:-",a,b,c,d,e)
# Out:
# the values are:- 4 5 15 20 26

# %%
#Question-2
# Create Five String Variables and Assigns Some Values in it and display the Output of that Variables
s1="hello"
s2="Welcome"
s3="To The"
s4="World"
s5="of Python Programming"

print("The Final output is:-",s1,s2,s3,s4,s5)
# Out:
# The Final output is:- hello Welcome To The World of Python Programming

# %%
#Question-3
# Store Days of the week  in One Variable

days = {"Mon","Tue","Web","Thu","Fri","Sat","Sun"}

print("Days of the week",days)
# Out:
# Days of the week {'Web', 'Fri', 'Sat', 'Thu', 'Mon', 'Tue', 'Sun'}

# %%
#Question-4
# Store at least 10  Floating point Number in one Variable

s1=[1.2,3.2,3.6,5.5,7.6,8.6,3.4,6.5,4.6,9.8]

print(s1)
# Out:
# [1.2, 3.2, 3.6, 5.5, 7.6, 8.6, 3.4, 6.5, 4.6, 9.8]

# %%
#Question-5
# Create a Dictionary to store the data of Square of the Given Nos upto 10

dict={x:x**2 for x in range(1,11)}

print(dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
#Question-6
# Create Five SET Variables and Assigns Some Values in it and display the Output of that Variables

a={1,2,3,4,5}
b={111,22,34,55,67}
c={"mon","tue","web"}
d={1,23,67,43,1}
e={22,33,44,44,56}

print(a,b,c,d,e)
# Out:
# {1, 2, 3, 4, 5} {34, 67, 22, 55, 111} {'tue', 'mon', 'web'} {1, 67, 43, 23} {56, 33, 44, 22}

# %%
#Question-7
# Create Five Tuples Variables and Assigns Some Values in it and display the Output of that Variables
